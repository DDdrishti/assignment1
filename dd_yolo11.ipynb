# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="/content/dataset_yolo11dd/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil

shutil.copytree(
    "/content/runs/detect/",
    "/content/drive/MyDrive/dd_yolo11_results1",
    dirs_exist_ok=True   # allows overwrite if folder already exists
)
# Out:
# '/content/drive/MyDrive/dd_yolo11_results1'

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")
# OR if saved in Drive:
# model = YOLO("/content/drive/MyDrive/dd_yolo11_results/train/weights/best.pt")

results = model.predict(
    source="/content/Problem Statement Scenario2 (1).mp4",   # path to your video
    save=True,                     # saves output video
    conf=0.25
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1593) /content/Problem Statement Scenario2 (1).mp4: 640x384 (no detections), 55.4ms
# video 1/1 (frame 2/1593) /content/Problem Statement Scenario2 (1).mp4: 640x384 (no detections), 8.0ms
# video 1/1 (frame 3/1593) /content/Problem Statement Scenario2 (1).mp4: 640x384 (no detections), 8.1ms
# video 1/1 (frame 4/1593) /content/Problem Statement Scenario2 (1).mp4: 640x384 (no detections), 8.8ms
# ...
